# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.optimize as opt
import seaborn as sns
from mpl_toolkits import mplot3d

def lsm0(x, y):
    k = np.mean(x*y) / np.mean(x**2)
    sigma_k = (1 / len(x))*np.sqrt((np.mean(y**2) / (np.mean(x**2))) - k**2)
    return k, sigma_k

# %%
lab = pd.read_excel("1.xlsx")
lab
# Out:
#        a  steps1  steps2  steps3  steps4  steps5
# 0      3       1       1       1       2       2
# 1     13       6       7       6       8       6
# 2     23      11      17      14      14      13
# 3     33      23      21      21      24      20
# 4     43      23      24      28      23      26
# ..   ...     ...     ...     ...     ...     ...
# 95   959     587     594     597     620     610
# 96   969     614     625     612     598     613
# 97   979     609     603     594     607     619
# 98   989     613     616     614     615     605
# 99  1000     615     627     611     631     643
#
# [100 rows x 6 columns]

# %%
lab["steps"] = lab[['steps1', 'steps2', 'steps3', 'steps4', 'steps5']].mean(axis=1)
lab
# Out:
#        a  steps1  steps2  steps3  steps4  steps5   time  steps
# 0      3       1       1       1       2       2    1.4    1.4
# 1     13       6       7       6       8       6    6.6    6.6
# 2     23      11      17      14      14      13   13.8   13.8
# 3     33      23      21      21      24      20   21.8   21.8
# 4     43      23      24      28      23      26   24.8   24.8
# ..   ...     ...     ...     ...     ...     ...    ...    ...
# 95   959     587     594     597     620     610  601.6  601.6
# 96   969     614     625     612     598     613  612.4  612.4
# 97   979     609     603     594     607     619  606.4  606.4
# 98   989     613     616     614     615     605  612.6  612.6
# 99  1000     615     627     611     631     643  625.4  625.4
#
# [100 rows x 8 columns]

# %%
plt.figure(figsize=(8,6), dpi = 600) # размер графика
plt.title(r"One dislocation")
plt.xlabel("$a$") # подписи к осям
plt.ylabel("$steps$")
plt.grid(True, linestyle="--") # пунктирная сетка
plt.plot(lab["a"], lab["steps"], '.')

# plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6), dpi = 600) # размер графика
plt.title(r"One dislocation")
plt.xlabel("$\ln(\dfrac{a}{a_0})$") # подписи к осям
plt.ylabel("$\ln(\dfrac{steps}{steps_0})$")
plt.grid(True, linestyle="--") # пунктирная сетка

lab["log_a"] = np.log(lab["a"] / min(lab["a"])) 
lab["log_steps"] = np.log(lab["steps"] / min(lab["steps"]))
k_steps, sigma_k_steps = lsm0(lab["log_a"], lab["log_steps"])

plt.plot(lab["log_a"], lab["log_steps"], 'b.', label="")
plt.plot(lab["log_a"], k_steps*lab["log_a"],'b--', 
         label=r"$k = (%.2f \pm %.2f)$" % (k_steps, sigma_k_steps))

plt.legend()
plt.show()

# %%
lab1 = pd.read_excel("2.xlsx")
lab1
# Out:
#         a  dislocations  steps1  steps2  steps3  steps3.1  steps4  steps5
# 0       3             1       0       2       0         0       4       2
# 1       6             1       0       1       2         1       4       1
# 2       6             2       6       3       0         0       4       0
# 3       9             1       2       6       8         7       1       0
# 4       9             2       5       5       3         0       7       1
# ...   ...           ...     ...     ...     ...       ...     ...     ...
# 5045  300            96     177     108     337        20      56      12
# 5046  300            97     164      99     303       191      56     149
# 5047  300            98       4     168     135       214      39     156
# 5048  300            99      11     129     234       150     356     124
# 5049  300           100     185      67     285       243      49     176
#
# [5050 rows x 8 columns]

# %%
lab1["steps"] = lab1[['steps1', 'steps2', 'steps3', 'steps4', 'steps5']].mean(axis=1)
lab1["frac"] = lab1["dislocations"] / lab1["a"]
lab1["frac"] *= lab1["frac"]
lab1["frac"] *= 100
lab1
# Out:
#         a  dislocations  steps1  steps2  steps3  steps3.1  steps4  steps5  \
# 0       3             1       0       2       0         0       4       2
# 1       6             1       0       1       2         1       4       1
# 2       6             2       6       3       0         0       4       0
# 3       9             1       2       6       8         7       1       0
# 4       9             2       5       5       3         0       7       1
# ...   ...           ...     ...     ...     ...       ...     ...     ...
# 5045  300            96     177     108     337        20      56      12
# 5046  300            97     164      99     303       191      56     149
# 5047  300            98       4     168     135       214      39     156
# 5048  300            99      11     129     234       150     356     124
# 5049  300           100     185      67     285       243      49     176
#
#       steps       frac
# 0       1.6  11.111111
# 1       1.6   2.777778
# 2       2.6  11.111111
# 3       3.4   1.234568
# 4       4.2   4.938272
# ...     ...        ...
# 5045  138.0  10.240000
# 5046  154.2  10.454444
# 5047  100.4  10.671111
# 5048  170.8  10.890000
# 5049  152.4  11.111111
#
# [5050 rows x 10 columns]

# %%
# sns.heatmap(lab1[['a', 'frac', 'steps']], linewidths=.5, annot=True, cbar=False, cmap='YlGnBu')
sns.heatmap(lab1[['a', 'frac', 'steps']])
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure(figsize=(17, 14))
# ax = fig.axes(projection='3d')
ax = fig.add_subplot(projection='3d')

# Data for a three-dimensional line
xline = lab1["a"]
yline = lab1["frac"]
zline = lab1["steps"]
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
xdata = lab1["a"]
ydata = lab1["frac"]
zdata = lab1["steps"]

ax.set_xlabel('$a$', fontsize=20)
ax.set_ylabel('$fractions, \%$', fontsize=20)
ax.set_zlabel('$steps$', fontsize=20)

ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='YlGnBu')

# %%
lab2 = pd.read_excel("3.xlsx")
lab2
# Out:
#                a  dislocations  steps1  steps2  steps3  steps3.1  steps4  \
# 0              3           1.0     3.0       1       2         1       2
# 1              3           2.0     0.0       3       2         0       7
# 2              3           3.0     1.0       3       4         1       3
# 3              6           1.0     1.0      10       2         0       5
# 4              6           2.0     4.0       3       1         3       2
# ...          ...           ...     ...     ...     ...       ...     ...
# 15145  300296325           NaN     NaN     295     405       317      69
# 15146        300         297.0     8.0     174     156       128     352
# 15147  300298387           NaN     NaN     375      49       103     411
# 15148        300         299.0     7.0     270     360       137     387
# 15149  300300366           NaN     NaN     265     300       198      34
#
#        steps5
# 0           3
# 1           1
# 2           0
# 3           4
# 4           8
# ...       ...
# 15145      17
# 15146      82
# 15147     354
# 15148     406
# 15149     442
#
# [15150 rows x 8 columns]

# %%
lab2["steps"] = lab2[['steps1', 'steps2', 'steps3', 'steps4', 'steps5']].mean(axis=1)
lab2["frac"] = lab2["dislocations"] / lab2["a"]
lab2
# Out:
#                a  dislocations  steps1  steps2  steps3  steps3.1  steps4  \
# 0              3           1.0     3.0       1       2         1       2
# 1              3           2.0     0.0       3       2         0       7
# 2              3           3.0     1.0       3       4         1       3
# 3              6           1.0     1.0      10       2         0       5
# 4              6           2.0     4.0       3       1         3       2
# ...          ...           ...     ...     ...     ...       ...     ...
# 15145  300296325           NaN     NaN     295     405       317      69
# 15146        300         297.0     8.0     174     156       128     352
# 15147  300298387           NaN     NaN     375      49       103     411
# 15148        300         299.0     7.0     270     360       137     387
# 15149  300300366           NaN     NaN     265     300       198      34
#
#        steps5   steps        frac
# 0           3    2.20   11.111111
# 1           1    2.60   44.444444
# 2           0    2.20  100.000000
# 3           4    4.40    2.777778
# 4           8    3.60   11.111111
# ...       ...     ...         ...
# 15145      17  196.50         NaN
# 15146      82  154.40   98.010000
# 15147     354  297.25         NaN
# 15148     406  286.00   99.334444
# 15149     442  260.25         NaN
#
# [15150 rows x 10 columns]

# %%
fig = plt.figure(figsize=(17, 14))
# ax = fig.axes(projection='3d')
ax = fig.add_subplot(projection='3d')

# Data for a three-dimensional line
xline = lab2["a"]
yline = lab2["frac"]
zline = lab2["steps"]
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
xdata = lab2["a"]
ydata = lab2["frac"]
zdata = lab2["steps"]

ax.set_xlabel('$a$', fontsize=20)
ax.set_ylabel('$fractions, \%$', fontsize=20)
ax.set_zlabel('$steps$', fontsize=20)

ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='YlGnBu')
